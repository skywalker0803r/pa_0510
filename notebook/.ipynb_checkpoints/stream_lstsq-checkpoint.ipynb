# %%
import numpy as np
import joblib
from sklearn.metrics import r2_score ,mean_squared_error
import pandas as pd

def mape(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# # data

# %%
# all data
data = joblib.load('../data/dataset.pkl')
b = data['stream']
batch_size = b.shape[0]
A = data['action'].reshape(batch_size,-1)

# %%
# split data
sp = 100000
A_train = A[:sp]
b_train = b[:sp]
A_test = A[sp:]
b_test = b[sp:]

# %% [markdown]
# # lstsq find w

# %%
from numpy.linalg import inv 
w = inv(A_train.T@A_train)@A_train.T@b_train
w.shape
# Out:
# (396, 1)

# %% [markdown]
# # evaluate

# %%
y_pred = A_train@w
y_real = b_train
score = pd.DataFrame(index = ['train'],columns = ['R2','MSE','MAPE'])
score['R2'] = r2_score(y_real,y_pred)
score['MSE'] = mean_squared_error(y_real,y_pred)
score['MAPE'] = mape(y_real,y_pred)
score
# Out:
#              R2       MSE      MAPE
# train  0.987839  0.000079  0.730562

# %%
y_pred = A_test@w
y_real = b_test
score2 = pd.DataFrame(index = ['test'],columns = ['R2','MSE','MAPE'])
score2['R2'] = r2_score(y_real,y_pred)
score2['MSE'] = mean_squared_error(y_real,y_pred)
score2['MAPE'] = mape(y_real,y_pred)
score2
# Out:
#             R2       MSE       MAPE
# test -4.740353  0.025766  22.120038

# %%
score.append(score2)
# Out:
#              R2       MSE       MAPE
# train  0.987839  0.000079   0.730562
# test  -4.740353  0.025766  22.120038

# %% [markdown]
# # check weight

# %%
s = np.linalg.lstsq(A_train,b_train,rcond=-1)[0]
s = s.reshape(36,11)

# %%
abs(pd.DataFrame(s,columns=data['action_col'])).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row0_col0 {
#             background-color:  #045585;
#             color:  #f1f1f1;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row0_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row0_col3 {
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row0_col4 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row0_col5 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row0_col7 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row0_col8 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row0_col9 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row0_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row1_col0 {
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row1_col1 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row1_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row1_col3 {
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row1_col4 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row1_col5 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row1_col7 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row1_col8 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row1_col9 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row1_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row2_col0 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row2_col1 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row2_col2 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row2_col3 {
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row2_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row2_col5 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row2_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row2_col7 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row2_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row2_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row2_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row3_col0 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row3_col1 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row3_col2 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row3_col3 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row3_col4 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row3_col5 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row3_col7 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row3_col8 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row3_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row3_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row4_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row4_col1 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row4_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row4_col3 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row4_col4 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row4_col5 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row4_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row4_col7 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row4_col8 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row4_col9 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row4_col10 {
#             background-color:  #03446a;
#             color:  #f1f1f1;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row5_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row5_col2 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row5_col3 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_4f4ffbfa_a187_11ea_82e2_b9faa7cfbbb2row5_col4 {
#             background-color:  #faf3f9;
#             color:  #000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(s,cmap='gray')
