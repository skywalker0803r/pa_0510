# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import joblib
import numpy as np
import warnings 
warnings.simplefilter('ignore')
os.listdir('../data')
# Out:
# ['dataset.pkl',
#  'PA_201605-2020001更新R10(20200602).csv',
#  'PA_201605-2020001更新R9(20200508).csv',
#  'tag_cleaned.csv',
#  'tag盤點表20200423.xlsx',
#  'tag盤點表20200602R1.xlsx',
#  'train_cleaned.csv']

# %%
data = joblib.load('../data/dataset.pkl')
action = np.array([data['mm_action'].inverse_transform(i) for i in data['action']])
feed = action[:,0,0]
output = data['mm_output'].inverse_transform(data['output']).reshape(-1)
plt.plot(feed,label='feed')
plt.plot(output,label='output')
plt.legend()
print('時間對入料和出料')
plt.show()

idx = np.random.randint(100000,size=10000)
plt.scatter(feed[idx],output[idx])
print('入料對出料')
plt.show()
# Out:
# 時間對入料和出料
# 入料對出料

# %%
n = 100000
target = feed[:n]/output[:n]
print('時間對單耗')
plt.plot(target)
plt.show()
plt.scatter(feed[idx],target[idx])
print('入料對單耗')
plt.show()
# Out:
# 時間對單耗
# 入料對單耗

# %% [markdown]
# # load tag

# %%
tag = pd.read_csv('../data/tag_cleaned.csv',index_col=0)
tag[tag.chinese.str.contains('蒸氣') == True]
# Out:
#     item                    TAG     chinese character   unit category period  \
# 27  28.0   MLPAP_FR-0755PV(轉換後)  反應槽16K蒸氣輸出        流量   T/HR   不可控制因子  1分鐘2筆
# 28  29.0       MLPAP_FR-0791.PV  反應槽50K蒸氣輸出        流量   T/HR   不可控制因子  1分鐘2筆
# 29  30.0  MLPAP_FI-V211.PV(轉換後)    副反應槽蒸氣輸出        流量  KG/HR   不可控制因子  1分鐘2筆
#
#    min   max 推測顯著性(依製程經驗)
# 27   0    25          ***
# 28  10    35          ***
# 29   0  6900          ***

# %%
temp_col = tag[tag.chinese.str.contains('鹽浴') == True][tag['category']=='可控制因子']
temp_col
# Out:
#     item                 TAG          chinese character unit category period  \
# 4    5.0  MLPAP_TJC-0757A.PV          反應槽鹽浴溫度        溫度    ℃    可控制因子  1分鐘2筆
# 7    8.0   MLPAP_PIC-0761.PV  鹽浴冷卻器(E112)出口壓力        壓力  BAR    可控制因子  1分鐘2筆
# 8    9.0   MLPAP_TRC-0762.PV  鹽浴冷卻器(E112)入口溫度        溫度    ℃    可控制因子  1分鐘2筆
# 88  89.0   MLPAP_TJC-0757.PV     反應器A/B側鹽浴溫度差        溫度    ℃    可控制因子  1分鐘2筆
# 94   5.0   MLPAP_TJ-0757B.PV          反應槽鹽浴溫度        溫度    ℃    可控制因子  1分鐘2筆
#
#     min  max 推測顯著性(依製程經驗)
# 4   345  365         ****
# 7    40   55          ***
# 8   345  365          ***
# 88   -3    3          ***
# 94  345  365         ****

# %%
temp_col = temp_col.TAG.values.tolist()
temp_col
# Out:
# ['MLPAP_TJC-0757A.PV',
#  'MLPAP_PIC-0761.PV',
#  'MLPAP_TRC-0762.PV',
#  'MLPAP_TJC-0757.PV',
#  'MLPAP_TJ-0757B.PV']

# %%
tag[tag.TAG.str.contains('0997') == True]
# Out:
#     item                TAG chinese character   unit category period   min  \
# 25  26.0  MLPAP_FQI-0997.PV  粗PA出料量        流量  KG/HR   不可控制因子  1分鐘2筆  5000
#
#       max 推測顯著性(依製程經驗)
# 25  10000          ***

# %%
tag[tag.TAG.str.contains('0619') == True]
# Out:
#    item               TAG chinese character   unit category period   min  \
# 3   4.0  MLPAP_FQ-0619.PV   OX入料量        流量  kg/HR    可控制因子  1分鐘2筆  2000
#
#     max 推測顯著性(依製程經驗)
# 3  8000         ****

# %%
tag[tag.chinese.str.contains('反應槽溫度') == True]
# Out:
#     item                  TAG             chinese character unit category  \
# 30  31.0     MLPAP_TJ-0706B02   反應槽溫度_多點式(高度 250)        溫度    ℃   不可控制因子
# 31  32.0     MLPAP_TJ-0706B03   反應槽溫度_多點式(高度 350)        溫度    ℃   不可控制因子
# 32  33.0     MLPAP_TJ-0706B04   反應槽溫度_多點式(高度 450)        溫度    ℃   不可控制因子
# 33  34.0     MLPAP_TJ-0706B05   反應槽溫度_多點式(高度 550)        溫度    ℃   不可控制因子
# 34  35.0     MLPAP_TJ-0706B06   反應槽溫度_多點式(高度 650)        溫度    ℃   不可控制因子
# 35  36.0     MLPAP_TJ-0706B07   反應槽溫度_多點式(高度 750)        溫度    ℃   不可控制因子
# 36  37.0     MLPAP_TJ-0706B08   反應槽溫度_多點式(高度 850)        溫度    ℃   不可控制因子
# 37  38.0     MLPAP_TJ-0706B09   反應槽溫度_多點式(高度 950)        溫度    ℃   不可控制因子
# 38  39.0     MLPAP_TJ-0706B10  反應槽溫度_多點式(高度 1050)        溫度    ℃   不可控制因子
# 39  40.0     MLPAP_TJ-0706B11  反應槽溫度_多點式(高度 1150)        溫度    ℃   不可控制因子
# 40  41.0     MLPAP_TJ-0706B12  反應槽溫度_多點式(高度 1250)        溫度    ℃   不可控制因子
# 41  42.0     MLPAP_TJ-0706B13  反應槽溫度_多點式(高度 1350)        溫度    ℃   不可控制因子
# 42  43.0     MLPAP_TJ-0706B14  反應槽溫度_多點式(高度 1450)        溫度    ℃   不可控制因子
# 43  44.0     MLPAP_TJ-0706B15  反應槽溫度_多點式(高度 1550)        溫度    ℃   不可控制因子
# 44  45.0     MLPAP_TJ-0706B16  反應槽溫度_多點式(高度 1650)        溫度    ℃   不可控制因子
# 45  46.0     MLPAP_TJ-0706B17  反應槽溫度_多點式(高度 1750)        溫度    ℃   不可控制因子
# 46  47.0     MLPAP_TJ-0706B18  反應槽溫度_多點式(高度 1850)        溫度    ℃   不可控制因子
# 47  48.0     MLPAP_TJ-0706B19  反應槽溫度_多點式(高度 1950)        溫度    ℃   不可控制因子
# 48  49.0     MLPAP_TJ-0706B20  反應槽溫度_多點式(高度 2050)        溫度    ℃   不可控制因子
# 49  50.0     MLPAP_TJ-0706B21  反應槽溫度_多點式(高度 2150)        溫度    ℃   不可控制因子
# 50  51.0     MLPAP_TJ-0706B22  反應槽溫度_多點式(高度 2250)        溫度    ℃   不可控制因子
# 51  52.0     MLPAP_TJ-0706B23  反應槽溫度_多點式(高度 2350)        溫度    ℃   不可控制因子
# 52  53.0     MLPAP_TJ-0706B24  反應槽溫度_多點式(高度 2450)        溫度    ℃   不可控制因子
# 53  54.0     MLPAP_TJ-0716A02   反應槽溫度_多點式(高度 250)        溫度    ℃   不可控制因子
# 54  55.0     MLPAP_TJ-0716A03   反應槽溫度_多點式(高度 350)        溫度    ℃   不可控制因子
# 55  56.0     MLPAP_TJ-0716A04   反應槽溫度_多點式(高度 450)        溫度    ℃   不可控制因子
# 56  57.0     MLPAP_TJ-0716A05   反應槽溫度_多點式(高度 550)        溫度    ℃   不可控制因子
# 57  58.0     MLPAP_TJ-0716A06   反應槽溫度_多點式(高度 650)        溫度    ℃   不可控制因子
# 58  59.0     MLPAP_TJ-0716A07   反應槽溫度_多點式(高度 750)        溫度    ℃   不可控制因子
# 59  60.0     MLPAP_TJ-0716A08   反應槽溫度_多點式(高度 850)        溫度    ℃   不可控制因子
# 60  61.0     MLPAP_TJ-0716A09   反應槽溫度_多點式(高度 950)        溫度    ℃   不可控制因子
# 61  62.0     MLPAP_TJ-0716A10  反應槽溫度_多點式(高度 1050)        溫度    ℃   不可控制因子
# 62  63.0     MLPAP_TJ-0716A11  反應槽溫度_多點式(高度 1150)        溫度    ℃   不可控制因子
# 63  64.0     MLPAP_TJ-0716A12  反應槽溫度_多點式(高度 1250)        溫度    ℃   不可控制因子
# 64  65.0     MLPAP_TJ-0716A13  反應槽溫度_多點式(高度 1350)        溫度    ℃   不可控制因子
# 65  66.0     MLPAP_TJ-0716A14  反應槽溫度_多點式(高度 1450)        溫度    ℃   不可控制因子
# 66  67.0     MLPAP_TJ-0716A15  反應槽溫度_多點式(高度 1550)        溫度    ℃   不可控制因子
# 67  68.0     MLPAP_TJ-0716A16  反應槽溫度_多點式(高度 1650)        溫度    ℃   不可控制因子
# 68  69.0     MLPAP_TJ-0716A17  反應槽溫度_多點式(高度 1750)        溫度    ℃   不可控制因子
# 69  70.0     MLPAP_TJ-0716A18  反應槽溫度_多點式(高度 1850)        溫度    ℃   不可控制因子
# 70  71.0     MLPAP_TJ-0716A19  反應槽溫度_多點式(高度 1950)        溫度    ℃   不可控制因子
# 71  72.0     MLPAP_TJ-0716A20  反應槽溫度_多點式(高度 2050)        溫度    ℃   不可控制因子
# 72  73.0     MLPAP_TJ-0716A21  反應槽溫度_多點式(高度 2150)        溫度    ℃   不可控制因子
# 73  74.0     MLPAP_TJ-0716A22  反應槽溫度_多點式(高度 2250)        溫度    ℃   不可控制因子
# 74  75.0     MLPAP_TJ-0716A23  反應槽溫度_多點式(高度 2350)        溫度    ℃   不可控制因子
# 75  76.0  MLPAP_TJR-0715A1.PV  反應槽溫度_多點式(高度 2450)        溫度    ℃   不可控制因子
#
#    period  min  max 推測顯著性(依製程經驗)
# 30  1分鐘2筆  340  450          ***
# 31  1分鐘2筆  340  450          ***
# 32  1分鐘2筆  340  450          ***
# 33  1分鐘2筆  340  450          ***
# 34  1分鐘2筆  340  450          ***
# 35  1分鐘2筆  340  450          ***
# 36  1分鐘2筆  340  450          ***
# 37  1分鐘2筆  340  450          ***
# 38  1分鐘2筆  340  450          ***
# 39  1分鐘2筆  340  450          ***
# 40  1分鐘2筆  340  450          ***
# 41  1分鐘2筆  340  450          ***
# 42  1分鐘2筆  340  450          ***
# 43  1分鐘2筆  340  450          ***
# 44  1分鐘2筆  340  450          ***
# 45  1分鐘2筆  340  450          ***
# 46  1分鐘2筆  340  450          ***
# 47  1分鐘2筆  340  450          ***
# 48  1分鐘2筆  340  450          ***
# 49  1分鐘2筆  340  450          ***
# 50  1分鐘2筆  340  450          ***
# 51  1分鐘2筆  340  450          ***
# 52  1分鐘2筆  340  450          ***
# 53  1分鐘2筆  340  450          ***
# 54  1分鐘2筆  340  450          ***
# 55  1分鐘2筆  340  450          ***
# 56  1分鐘2筆  340  450          ***
# 57  1分鐘2筆  340  450          ***
# 58  1分鐘2筆  340  450          ***
# 59  1分鐘2筆  340  450          ***
# 60  1分鐘2筆  340  450          ***
# 61  1分鐘2筆  340  450          ***
# 62  1分鐘2筆  340  450          ***
# 63  1分鐘2筆  340  450          ***
# 64  1分鐘2筆  340  450          ***
# 65  1分鐘2筆  340  450          ***
# 66  1分鐘2筆  340  450          ***
# 67  1分鐘2筆  340  450          ***
# 68  1分鐘2筆  340  450          ***
# 69  1分鐘2筆  340  450          ***
# 70  1分鐘2筆  340  450          ***
# 71  1分鐘2筆  340  450          ***
# 72  1分鐘2筆  340  450          ***
# 73  1分鐘2筆  340  450          ***
# 74  1分鐘2筆  340  450          ***
# 75  1分鐘2筆  340  450          ***

# %% [markdown]
# # load df

# %%
df = pd.read_csv('../data/train_cleaned.csv',index_col=0)

# %% [markdown]
# # kde

# %%
for i in tag[tag.chinese.str.contains('反應槽溫度') == True].TAG.values[:5]:
    h = tag.loc[tag.TAG==i,'chinese'].values[0].split('高度')[1][:-1]
    df[i].sample(1000).plot(kind='kde',label=h)
plt.legend()
plt.show()

# %% [markdown]
# # RAW

# %%
col = tag[tag.chinese.str.contains('反應槽溫度') == True].TAG.values
X = df[col].dropna(axis=0)
plt.plot(X.values)
# Out:
# [<matplotlib.lines.Line2D at 0x28c70cf6908>,
#  <matplotlib.lines.Line2D at 0x28c70cf6788>,
#  <matplotlib.lines.Line2D at 0x28c70cf6e08>,
#  <matplotlib.lines.Line2D at 0x28c70cf6f08>,
#  <matplotlib.lines.Line2D at 0x28c70e1b688>,
#  <matplotlib.lines.Line2D at 0x28c70e1b0c8>,
#  <matplotlib.lines.Line2D at 0x28c70e1b788>,
#  <matplotlib.lines.Line2D at 0x28c70e1ba08>,
#  <matplotlib.lines.Line2D at 0x28c70e1b288>,
#  <matplotlib.lines.Line2D at 0x28c70e1b908>,
#  <matplotlib.lines.Line2D at 0x28c70b87cc8>,
#  <matplotlib.lines.Line2D at 0x28c70df1f08>,
#  <matplotlib.lines.Line2D at 0x28c70df1a48>,
#  <matplotlib.lines.Line2D at 0x28c70df11c8>,
#  <matplotlib.lines.Line2D at 0x28c70df1c08>,
#  <matplotlib.lines.Line2D at 0x28c70df1f48>,
#  <matplotlib.lines.Line2D at 0x28c70e04608>,
#  <matplotlib.lines.Line2D at 0x28c70e04c88>,
#  <matplotlib.lines.Line2D at 0x28c70e047c8>,
#  <matplotlib.lines.Line2D at 0x28c70e04748>,
#  <matplotlib.lines.Line2D at 0x28c70e04d88>,
#  <matplotlib.lines.Line2D at 0x28c70e04148>,
#  <matplotlib.lines.Line2D at 0x28c70d2cd88>,
#  <matplotlib.lines.Line2D at 0x28c70d2c888>,
#  <matplotlib.lines.Line2D at 0x28c70d2c948>,
#  <matplotlib.lines.Line2D at 0x28c70d2c648>,
#  <matplotlib.lines.Line2D at 0x28c70d2c208>,
#  <matplotlib.lines.Line2D at 0x28c70d2cf88>,
#  <matplotlib.lines.Line2D at 0x28c70bf0dc8>,
#  <matplotlib.lines.Line2D at 0x28c70bf0f88>,
#  <matplotlib.lines.Line2D at 0x28c70bf0488>,
#  <matplotlib.lines.Line2D at 0x28c70ba26c8>,
#  <matplotlib.lines.Line2D at 0x28c70ba2708>,
#  <matplotlib.lines.Line2D at 0x28c70ba2248>,
#  <matplotlib.lines.Line2D at 0x28c70ba2808>,
#  <matplotlib.lines.Line2D at 0x28c70ba2388>,
#  <matplotlib.lines.Line2D at 0x28c70d0bf88>,
#  <matplotlib.lines.Line2D at 0x28c70d0b7c8>,
#  <matplotlib.lines.Line2D at 0x28c70d0b088>,
#  <matplotlib.lines.Line2D at 0x28c70d0bb08>,
#  <matplotlib.lines.Line2D at 0x28c70d0bec8>,
#  <matplotlib.lines.Line2D at 0x28c710e7148>,
#  <matplotlib.lines.Line2D at 0x28c710e7088>,
#  <matplotlib.lines.Line2D at 0x28c710e7bc8>,
#  <matplotlib.lines.Line2D at 0x28c710e7488>,
#  <matplotlib.lines.Line2D at 0x28c710e77c8>]

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import SparsePCA
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
pca = SparsePCA(n_components=5)

X = ss.fit_transform(X)
X = pca.fit_transform(X)

X = pd.DataFrame(X,columns=['pca{}'.format(i) for i in range(5)])
X.plot()

# %%
pca.components_
# Out:
# array([[ 3.05601752e-02,  1.71495333e-02,  0.00000000e+00,
#         -2.13455577e-02, -1.50533373e-02, -5.58564855e-03,
#         -5.58149347e-04,  0.00000000e+00,  8.19813366e-02,
#          1.65431348e-01,  2.41054987e-01,  2.61333886e-01,
#          2.69899226e-01,  2.69028640e-01,  2.58933115e-01,
#          2.34961098e-01,  1.92615783e-01,  1.49759703e-01,
#          1.05780950e-01,  8.51412405e-02,  0.00000000e+00,
#         -3.84225469e-02, -9.02512508e-02,  0.00000000e+00,
#          1.12296056e-02,  0.00000000e+00, -1.12508609e-02,
#         -1.00305283e-02, -1.00282617e-02, -2.90784822e-02,
#         -3.16603079e-02,  0.00000000e+00,  5.49285324e-02,
#          1.78962820e-01,  2.42893730e-01,  2.54788535e-01,
#          2.47737069e-01,  2.56119583e-01,  2.46081825e-01,
#          2.24058475e-01,  1.84022525e-01,  1.47224457e-01,
#          1.31512751e-01,  9.73892887e-02,  3.40547880e-02,
#         -5.73140702e-03],
#        [-2.11072219e-03,  2.86233843e-02,  3.11618514e-02,
#          2.69688657e-02, -4.60024993e-04, -1.43009825e-02,
#         -7.22002617e-02, -1.18247273e-02,  1.70606273e-02,
#          3.60554356e-02,  0.00000000e+00, -5.32188445e-02,
#         -3.16859910e-02, -2.85712325e-02, -6.13972163e-02,
#         -1.14619113e-01, -1.78994619e-01, -2.23569363e-01,
#         -2.59320528e-01, -3.03524477e-01, -3.62704760e-01,
#         -3.58262477e-01, -2.96056996e-01, -4.68358647e-02,
#         -3.41419733e-02, -3.39341660e-03,  2.67004235e-03,
#          0.00000000e+00,  6.70802452e-03,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.51077352e-02,
#          1.45021922e-02,  9.49496051e-05,  5.47922875e-03,
#         -1.38531979e-03,  1.19510389e-02, -7.50428667e-02,
#         -1.31631215e-01, -1.86811317e-01, -2.23901136e-01,
#         -2.57860211e-01, -2.97800461e-01, -3.26861723e-01,
#         -7.60023050e-02],
#        [-1.20310861e-01, -6.85964834e-02, -3.28572815e-02,
#          0.00000000e+00,  1.65024701e-02,  4.40285664e-02,
#          1.52341432e-01,  3.92262049e-01,  3.69341716e-01,
#          2.80510559e-01,  1.33254788e-01,  1.60532458e-02,
#          1.55185709e-02,  1.37831520e-02,  0.00000000e+00,
#         -2.19302212e-02, -4.75381092e-02, -4.76976161e-02,
#         -4.13562762e-02, -1.93819385e-02,  5.67584955e-02,
#          7.54863712e-02,  7.04079328e-02, -1.22258426e-01,
#         -1.20778376e-01, -9.14997589e-02, -6.19422945e-02,
#         -4.43123882e-02, -1.58215086e-02,  6.21536639e-02,
#          2.73012467e-01,  3.89330996e-01,  3.87180838e-01,
#          2.57260034e-01,  1.29338264e-01,  9.45462808e-02,
#          9.33047184e-02,  8.58671706e-02,  2.20309300e-02,
#         -3.32366235e-02, -6.12963652e-02, -7.11126412e-02,
#         -5.54440661e-02, -2.60165388e-02,  0.00000000e+00,
#          0.00000000e+00],
#        [-3.68944788e-01, -2.75393497e-01, -2.04757895e-01,
#         -1.48545245e-01, -1.15826234e-01, -8.30735163e-02,
#          0.00000000e+00,  1.79980394e-02,  1.73980374e-02,
#         -1.19004890e-02, -1.77814978e-02,  0.00000000e+00,
#          1.84103503e-02,  3.13278256e-02,  3.12389034e-02,
#          2.76132863e-02,  1.62647075e-02, -1.32692954e-02,
#         -5.46284074e-02, -3.78026799e-05, -4.33632870e-02,
#         -1.13603944e-01, -2.41949337e-01, -3.92637969e-01,
#         -3.11568734e-01, -2.33812673e-01, -1.95980289e-01,
#         -1.48666607e-01, -1.21457810e-01, -5.05519058e-02,
#          1.90715393e-02,  4.09194718e-02,  2.00654605e-02,
#          0.00000000e+00,  0.00000000e+00,  2.10764362e-02,
#          3.46099729e-02,  0.00000000e+00,  1.59511986e-02,
#          1.61261543e-03, -6.11263237e-03, -2.37487721e-02,
#          7.00484617e-03,  2.67388244e-03, -5.50162855e-02,
#         -4.80714283e-01],
#        [-9.08902170e-02, -2.12095196e-01, -2.56923421e-01,
#         -2.75498935e-01, -2.95225701e-01, -3.14456536e-01,
#         -3.20741211e-01, -1.37437701e-01,  6.08912314e-03,
#          3.51733417e-02,  3.01669528e-02,  4.42451930e-03,
#         -1.27270578e-03,  0.00000000e+00, -5.81636064e-04,
#          3.51649805e-03,  1.32728073e-02,  3.36328833e-02,
#          4.84270991e-02,  3.59362574e-03, -2.49460771e-02,
#         -1.19277495e-02,  0.00000000e+00,  0.00000000e+00,
#         -1.26394012e-01, -2.15690799e-01, -2.44545560e-01,
#         -2.75666497e-01, -2.94060536e-01, -3.10316592e-01,
#         -2.50167511e-01, -1.21014491e-01,  0.00000000e+00,
#          3.24660148e-02,  2.10418720e-02,  1.47361923e-02,
#          1.99017825e-02,  2.54164494e-02,  1.43433650e-02,
#          1.20639485e-02,  1.81218741e-02,  2.66707866e-02,
#         -3.96821297e-03, -3.99951767e-02, -5.05578286e-02,
#          1.54222659e-01]])

# %%
import numpy as np
np.round(pca.components_,2)
# Out:
# array([[ 0.03,  0.02,  0.  , -0.02, -0.02, -0.01, -0.  ,  0.  ,  0.08,
#          0.17,  0.24,  0.26,  0.27,  0.27,  0.26,  0.23,  0.19,  0.15,
#          0.11,  0.09,  0.  , -0.04, -0.09,  0.  ,  0.01,  0.  , -0.01,
#         -0.01, -0.01, -0.03, -0.03,  0.  ,  0.05,  0.18,  0.24,  0.25,
#          0.25,  0.26,  0.25,  0.22,  0.18,  0.15,  0.13,  0.1 ,  0.03,
#         -0.01],
#        [-0.  ,  0.03,  0.03,  0.03, -0.  , -0.01, -0.07, -0.01,  0.02,
#          0.04,  0.  , -0.05, -0.03, -0.03, -0.06, -0.11, -0.18, -0.22,
#         -0.26, -0.3 , -0.36, -0.36, -0.3 , -0.05, -0.03, -0.  ,  0.  ,
#          0.  ,  0.01,  0.  ,  0.  ,  0.  ,  0.02,  0.01,  0.  ,  0.01,
#         -0.  ,  0.01, -0.08, -0.13, -0.19, -0.22, -0.26, -0.3 , -0.33,
#         -0.08],
#        [-0.12, -0.07, -0.03,  0.  ,  0.02,  0.04,  0.15,  0.39,  0.37,
#          0.28,  0.13,  0.02,  0.02,  0.01,  0.  , -0.02, -0.05, -0.05,
#         -0.04, -0.02,  0.06,  0.08,  0.07, -0.12, -0.12, -0.09, -0.06,
#         -0.04, -0.02,  0.06,  0.27,  0.39,  0.39,  0.26,  0.13,  0.09,
#          0.09,  0.09,  0.02, -0.03, -0.06, -0.07, -0.06, -0.03,  0.  ,
#          0.  ],
#        [-0.37, -0.28, -0.2 , -0.15, -0.12, -0.08,  0.  ,  0.02,  0.02,
#         -0.01, -0.02,  0.  ,  0.02,  0.03,  0.03,  0.03,  0.02, -0.01,
#         -0.05, -0.  , -0.04, -0.11, -0.24, -0.39, -0.31, -0.23, -0.2 ,
#         -0.15, -0.12, -0.05,  0.02,  0.04,  0.02,  0.  ,  0.  ,  0.02,
#          0.03,  0.  ,  0.02,  0.  , -0.01, -0.02,  0.01,  0.  , -0.06,
#         -0.48],
#        [-0.09, -0.21, -0.26, -0.28, -0.3 , -0.31, -0.32, -0.14,  0.01,
#          0.04,  0.03,  0.  , -0.  ,  0.  , -0.  ,  0.  ,  0.01,  0.03,
#          0.05,  0.  , -0.02, -0.01,  0.  ,  0.  , -0.13, -0.22, -0.24,
#         -0.28, -0.29, -0.31, -0.25, -0.12,  0.  ,  0.03,  0.02,  0.01,
#          0.02,  0.03,  0.01,  0.01,  0.02,  0.03, -0.  , -0.04, -0.05,
#          0.15]])
